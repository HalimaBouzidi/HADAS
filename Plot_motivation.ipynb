# %%
import csv
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import autograd.numpy as anp
import numpy as np
from matplotlib.ticker import AutoMinorLocator

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('plot_style.txt')

models = ['a0', 'a6', 'b1' , 'b2']
base_enrgy = [173.7836539, 335.4857277, 212.4440779, 341.302747]
eex_enrgy = [119.8392595, 256.8086068, 119.8449266, 187.9260796]
eex_dvfs_enrgy = [116.1411463, 218.3405264, 93.78743745, 126.061052]

fig, ax = plt.subplots(figsize=(4, 3))
ax.set_facecolor('#EBEBEB')
[ax.spines[side].set_visible(False) for side in ax.spines]
ax.grid(which='major', color='white', linewidth=1.2)
ax.grid(which='minor', color='white', linewidth=0.6)
ax.minorticks_on()
ax.tick_params(which='minor', bottom=False, left=False)
ax.xaxis.set_minor_locator(AutoMinorLocator(2))
ax.yaxis.set_minor_locator(AutoMinorLocator(2))
ax.set_axisbelow(True)
x = np.arange(4)
width = 0.23

# plot data in grouped manner of bar type
plt.bar(x-0.25, base_enrgy, width, color='#063951', linewidth=0)
plt.bar(x, eex_enrgy, width, color='#ffa700', linewidth=0, hatch='..')
plt.bar(x+0.25, eex_dvfs_enrgy, width, color='#b50000', linewidth=0, hatch='/')
plt.xticks(x, ['a0', 'a6', 'b1', 'b2'])
plt.xlabel("DyNNs")
plt.ylabel("Energy consumption (mJ)")
plt.ylim([50, 420])
plt.legend(["Baseline Energy", "EEx Energy", "EEx_DVFS Energy"], bbox_to_anchor=(0.501, 1.22), 
           loc='upper center', ncol=3, borderaxespad=5, fontsize=7, borderpad=0.5)
plt.show()
#plt.savefig('./energy_motiv.pdf', dpi=300)

# %%
import matplotlib
import matplotlib.pyplot as plt
plt.style.use('plot_style.txt')

models = ['a0', 'a6', 'b1' , 'b2']
base_acc = [86.3299942,87.33999634,88.22999573,88.05999756]
eex_acc = [89.95,93.02,93.16,91.83]
eex_dvfs_acc = [89.95,93.02,93.16,91.83]

fig, ax = plt.subplots(figsize=(4, 3))
ax.set_facecolor('#EBEBEB')
[ax.spines[side].set_visible(False) for side in ax.spines]
ax.grid(which='major', color='white', linewidth=1.2)
ax.grid(which='minor', color='white', linewidth=0.6)
ax.minorticks_on()
ax.tick_params(which='minor', bottom=False, left=False)
ax.xaxis.set_minor_locator(AutoMinorLocator(2))
ax.yaxis.set_minor_locator(AutoMinorLocator(2))
ax.set_axisbelow(True)
x = np.arange(4)
width = 0.23

# plot data in grouped manner of bar type
plt.bar(x-0.25, base_acc, width, color='#063951', linewidth=0)
plt.bar(x, eex_acc, width, color='#0d95bc', linewidth=0, hatch='..')
plt.bar(x+0.25, eex_dvfs_acc, width, color='#a2b969', linewidth=0, hatch='/')
plt.xticks(x, ['a0', 'a6', 'b1', 'b2'])
plt.xlabel("DyNNs")
plt.ylabel("TOP-1 Accuracy (%)")
plt.ylim([85, 95])
plt.legend(["Baseline Acc", "EEx Acc", "EEx_DVFS Acc"], bbox_to_anchor=(0.501, 1.22), 
           loc='upper center', ncol=3, borderaxespad=5, fontsize=7.5, borderpad=0.5)
plt.show()
#plt.savefig('./accuracy_motiv.pdf', dpi=300)
